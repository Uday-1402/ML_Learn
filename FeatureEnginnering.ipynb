# %% [markdown]
# <a href="https://colab.research.google.com/github/Uday-1402/ML_Learn/blob/main/FeatureEnginnering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature Enginnering

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Feature Transformation

# %%
# First step is to handle missing values :- (remove or fill (replace by mean, median etc.))

# %%
# Handling categorical values (scikit.learn accepts only numerical values.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Outlier detection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#    With Outliers                    Outliers removed

# %%
# Feature Scaling

# %% [markdown]
# ## Feature Construction

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ## Feature Extraction
